# %% [markdown]
# # Лабораторная работа №2

# %% [markdown]
# ## Выполнил студент группы БВТ1905 Максимов Данила Васильевич

# %% [markdown]
# ### Задание №1

# %% [markdown]
# Реализовать методы поиска в соответствии с заданием. Организовать генерацию начального набора случайных данных. Для всех вариантов добавить реализацию добавления, поиска и удаления элементов. Оценить время работы каждого алгоритма поиска и сравнить его со временем работы стандартной функции поиска, используемой в выбранном языке программирования.

# %%
import time
import random

# генерация начального набора случайных данных
from random import randint
def generation(size, minimum, maximum):
    array = [randint(minimum, maximum) for i in range(size)]
    array = sorted(array)
    return array
array = generation(1000, -1000, 1000)

# %%
# бинарный поиск
def bin_sr(array, key):
    low_b = 0
    up_b = len(array) - 1
    while low_b <= up_b:
        center = (low_b + up_b) // 2
        if array[center] == key:
            return center
        elif array[center] > key:
            up_b = center - 1
        elif array[center] < key:
            low_b = center + 1
    return None

start = time.time()
bin_sr(sorted(array), 0)
finish_z = time.time()
print("Время бинарного поиска для нулевого элемента: ", (finish_z - start) * 1000)
# Out:
# Время бинарного поиска для нулевого элемента:  0.08320808410644531

# %%
# бинарное дерево
class node:
    # Инициализация узла. Значения левого ребенка, правого ребенка и родителя изначально заданы None, т.к. их может не быть вовсе.
    def __init__(self, value=None):
        self.value = value
        self.left_child = None
        self.right_child = None
        self.parent = None


class binary_search_tree:
    # Инициализация бинарного дерева. Корня изначально нет.
    def __init__(self):
        self.root = None

    def insert(self, value):
        # Когда корня нет - создать новый корень
        if self.root == None:
            self.root = node(value)
        else:
            self._insert(value, self.root)

    def _insert(self, value, cur_node):
        # cur node - текущий узел
        # Если значение меньше текущего узла
        if value < cur_node.value:
            # Если нет левого ребенка
            if cur_node.left_child == None:
                # Установка левого ребенка
                cur_node.left_child = node(value)
                # Установка родителя для левого ребенка
                cur_node.left_child.parent = cur_node
            else:
                # Рекурсивно вызываем эту функцию для левого ребенка
                self._insert(value, cur_node.left_child)
        # Если значение больше текущего узла
        elif value > cur_node.value:
            # Если нет правого ребенка
            if cur_node.right_child == None:
                # Установка правого ребенка
                cur_node.right_child = node(value)
                # Установка родителя для правого ребенка
                cur_node.right_child.parent = cur_node
            else:
                # Рекурсивно вызываем эту функцию для правого ребенка
                self._insert(value, cur_node.right_child)

    # Поиск элемента в дереве
    def search(self, value):
        # Если есть корень
        if self.root != None:
            return self._search(value, self.root)
        else:
             return False

    # Поиск элемента в дереве
    def _search(self, value, cur_node):
        # Если значение совпадает с текущим значением
        if value == cur_node.value:
            return True
        # Если значение меньше текущего значения и есть левый ребенок
        elif value < cur_node.value and cur_node.left_child != None:
            # Рекурсивно вызывает поиск для левого ребенка
            return self._search(value, cur_node.left_child)
        # Если значение больше текущего значения и есть правый ребенок
        elif value > cur_node.value and cur_node.right_child != None:
            # Рекурсивно вызывает поиск для правого ребенка
            return self._search(value, cur_node.right_child)
        return False

    def delete_value(self, value):
        global array
        global tree
        while value in array:
            array.remove(value)
        new_tree = binary_search_tree()
        for number in array:
            new_tree.insert(number)
        tree = new_tree

# Время старта
start = time.time()

tree = binary_search_tree()
for number in array:
    tree.insert(number)
# Время после построения дерева
tree_time = time.time() - start

tree.search(0)
# Время после поиска
first = time.time() - start

# Время на построение и поиск нулевого элемента
print("Время построения дерева и поиска нулевого элемента:", first)
# Out:
# Время построения дерева и поиска нулевого элемента: 0.14965319633483887

# %%
# Фибоначчиев поиск
def fib_sr(array, element):
    position = 0
    left = 0
    right = 1
    while array[left] != element:
        left = 0
        right = 1
        while array[right - 1] < element:
            left,right = right, left
            right += left
            if right > len(array):
                right = len(array)
        array = array[left:right]
        position += left
        right = len(array)
        left = 0
        if len(array) == 1 and array[0] != element:
            return None
    return position

start = time.time()
fib_sr(sorted(array), 0)
finish_z = time.time()
print("Время поиска Фибоначчи для нулевого элемента: ", (finish_z - start) * 1000)
# Out:
# Время поиска Фибоначчи для нулевого элемента:  0.091552734375

# %%
# интерполяционный поиск
def interpolation_search(array, element):
    left = 0
    right = len(array) - 1
    while array[left] < element and array[right] > element:
        if array[left] == array[right]:
            break
        index = (element - array[left]) * (left - right)//(array[left] - array[right]) + left
        if array[index] > element:
            right = index - 1
        elif array[index] < element:
            left = index + 1
        else:
            return index
    if array[left] == element:
        return left
    if array[right] == element:
        return right
    return None

start = time.time()
interpolation_search(sorted(array), 0)
finish_z = time.time()
print("Время интерполяционного поиска для элемента 0:", (finish_z - start) * 1000)
# Out:
# Время интерполяционного поиска для элемента 0: 0.080108642578125

# %%
start = time.time()
print(0 in array)
print("Время стандартного поиска для нулевого элемента:", (time.time() - start) * 1000)
# Out:
# False
# Время стандартного поиска для нулевого элемента: 0.3066062927246094

# %% [markdown]
# ### Задание №2

# %% [markdown]
# Реализовать три метода рехеширования.

# %%
# Простое рехеширование
class EasyRehash:
    def __init__(self, data):
        self.data = data.split(" ")
        self.array = [None] * len(self.data)
        self.size = len(self.data)

    def hash(self, array):
        s = 0
        for number in range(len(array)):
            s = s + ord(array[number])
        return s % self.size

    def _rehash(self, pos, i):
        return (pos + i) % self.size

    def rehash(self):
        for char_number in range(self.size):
            i = 0
            if self.array[self.hash(self.data[char_number])] == None:
                self.array[self.hash(self.data[char_number])] = self.data[char_number]
            else:
                while self.array[self._rehash(self.hash(self.data[char_number]), i)] != None:
                    i += 1
                self.array[self._rehash(self.hash(self.data[char_number]), i)] = self.data[char_number]

    def _search(self, element):
        return self.array.index(element)

    def search(self, element):
        if element in self.array:
            return self._search(element)
        else:
            print("Элемент {} не был хеширован".format(element))

    def _delete(self, number):
        self.size -= 1
        self.data.pop(number)
        self.array = [None] * self.size
        self.rehash()

    def delete(self, element):
        num = self.search(element)
        if type(num) == int:
            self._delete(num)

    def add(self, element):
        self.size += 1
        self.data.append(element)
        self.array = [None] * self.size
        self.rehash()
        
data = "a b c d e f g n r o b b"
print("Исходные данные:", data + "\n")
easy = EasyRehash(data)
easy.rehash()
print("Простое рехеширование:", easy.array)
easy.delete("b")
print("Удаление в простом рехэшировании:", easy.array)
easy.add("m")
print("Добавление в простом рехэшировании:", easy.array)
# Out:
# Исходные данные: a b c d e f g n r o b b
#
# Простое рехеширование: ['b', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'n', 'r', 'o', 'b']
# Удаление в простом рехэшировании: ['c', 'd', 'e', 'f', 'g', 'n', 'r', 'o', 'b', 'b', 'b']
# Добавление в простом рехэшировании: ['b', 'm', 'b', 'c', 'd', 'e', 'f', 'g', 'n', 'r', 'o', 'b']

# %%
# Рехэширование с помощью псевдослучайных чисел
class RandRehash(EasyRehash):
    def rehash(self):
        for char_number in range(self.size):
            i = 0
            if self.array[self.hash(self.data[char_number])] == None:
                self.array[self.hash(self.data[char_number])] = self.data[char_number]
            else:
                while self.array[self._rehash(self.hash(self.data[char_number]), i)] != None:
                    i = random.randint(1, self.size)
                self.array[self._rehash(self.hash(self.data[char_number]), i)] = self.data[char_number]
                
data = "a b c d e f g n r o b b"
print("Исходные данные:", data + "\n")
rand = RandRehash(data)
rand.rehash()
print("Рандомное рехеширование:", rand.array)
rand.delete("b")
print("Удаление в рандомном рехэшировании:", rand.array)
rand.add("m")
print("Добавление в рандомном рехэшировании:", rand.array)
# Out:
# Исходные данные: a b c d e f g n r o b b
#
# Рандомное рехеширование: ['r', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'b', 'n', 'b', 'o']
# Удаление в рандомном рехэшировании: ['n', 'd', 'e', 'f', 'g', 'r', 'o', 'b', 'b', 'a', 'b']
# Добавление в рандомном рехэшировании: ['n', 'a', 'b', 'o', 'd', 'e', 'f', 'g', 'b', 'r', 'm', 'b']

# %%
# Метод цепочек
class ChainRehash:
    def __init__(self, data):
        self.data = data.split(" ")
        self.array = [None] * len(self.data)
        self.size = len(self.data)

    def hash(self, array):
        sum = 0
        for number in range(len(array)):
            sum = sum + ord(array[number])
        return sum % self.size

    def rehash(self):
        for i in range(self.size):
            if self.array[self.hash(self.data[i])] == None:
                self.array[self.hash(self.data[i])] = self.data[i]
            elif self.array[self.hash(self.data[i])] != None:
                prevValue = self.array[self.hash(self.data[i])]
                if type(prevValue) != list:
                    self.array[self.hash(self.data[i])] = [prevValue]
                self.array[self.hash(self.data[i])].append(self.data[i])
        return self.array

    def find_value(self, key):
        for number, element in enumerate(self.array):
            if (type(element) is list):
                for number2, element2 in enumerate(self.array[number]):
                    if (element2 == key):
                        return [number, number2]
            else:
                if (element == key):
                    return [number]
        print("Элемент {} не был хеширован".format(key))

    def delete(self, element):
        lst = self.find_value(element)
        if type(lst) != None:
            self.data.remove(element)
            self.size -= 1
            self.array = [None] * self.size
            self.rehash()

    def add(self, element):
        self.data.append(element)
        self.size += 1
        self.array = [None] * self.size
        self.rehash()

data = "a b c d e f g n r o b b"
print("Исходные данные:", data + "\n")
chain = ChainRehash(data)
chain.rehash()
print("Рехеширование методом цепочек:", chain.array)
chain.delete("b")
print("Удаление в рехешировании методом цепочек:", chain.array)
chain.add("m")
print("Добавление в рехешировании методом цепочек:", chain.array)
# Out:
# Исходные данные: a b c d e f g n r o b b
#
# Рехеширование методом цепочек: [None, 'a', ['b', 'n', 'b', 'b'], ['c', 'o'], 'd', 'e', ['f', 'r'], 'g', None, None, None, None]
# Удаление в рехешировании методом цепочек: [['c', 'n'], ['d', 'o'], 'e', 'f', ['g', 'r'], None, None, None, None, 'a', ['b', 'b']]
# Добавление в рехешировании методом цепочек: [None, ['a', 'm'], ['n', 'b', 'b'], ['c', 'o'], 'd', 'e', ['f', 'r'], 'g', None, None, None, None]

# %% [markdown]
# ### Задание №3

# %% [markdown]
# Расставить на стандартной 64-клеточной шахматной доске 8 ферзей так, чтобы ни один из них не находился под боем другого». Подразумевается, что ферзь бьёт все клетки, расположенные по вертикалям, горизонталям и обеим диагоналям. Написать программу, которая находит хотя бы один способ решения задач.

# %%
# Установка ферзя
def set_ferz(i, j):
    for x in range(8):
        # Прибавка единиц по вертикали
        board[x][j] += 1
        # Прибавка единиц по горизонтали
        board[i][x] += 1
        # Прибавка единиц по диагоналям
        # Второстепенная
        if 0 <= i + j - x < 8:
            board[i + j - x][x] += 1
        # Главная
        if 0 <= i - j + x < 8:
            board[i - j + x][x] += 1
    # Позицию ферзя принимаем за -1
    board[i][j] = -1

# Удаление ферзя
def delete_ferz(i, j):
    # Позицию ферзя принимаем за -1
    for x in range(8):
        # Уменьшение единиц по вертикали
        board[x][j] -= 1
        # Уменьшение единиц по горизонтали
        board[i][x] -= 1
        # Уменьшение единиц по диагоналям
        # Второстепенная
        if 0 <= i + j - x < 8:
            board[i + j - x][x] -= 1
        # Главная
        if 0 <= i - j + x < 8:
            board[i - j + x][x] -= 1
    # Позицию удаленного ферзя принимаем за 0
    board[i][j] = 0

# Печать позиции на доске из числовой матрицы
def print_coord():
    alphabet = "ABCDEFGH"
    coord = []
    for i in range(8):
        for j in range(8):
            if board[i][j] == -1:
                coord.append(alphabet[j] + str(i + 1))
    print(coord)

def solve(i):
    # Пробегаемся по столбцам
    for j in range(8):
        # Если 0, то это возможное расположение ферзя
        if board[i][j] == 0:
            set_ferz(i, j)
            # Если это последняя строка, то расстановка верная
            if i == 7:
                # Выводим доску
                print_coord()
            # Иначе вызывыаем следующую строку
            else:
                solve(i + 1)
            delete_ferz(i, j)

# Задаем матрицу нулей, размером с шахматную доску
board = [[0 for i in range(8)] for j in range(8)]
solve(0)
# Out:
# ['A1', 'E2', 'H3', 'F4', 'C5', 'G6', 'B7', 'D8']
# ['A1', 'F2', 'H3', 'C4', 'G5', 'D6', 'B7', 'E8']
# ['A1', 'G2', 'D3', 'F4', 'H5', 'B6', 'E7', 'C8']
# ['A1', 'G2', 'E3', 'H4', 'B5', 'D6', 'F7', 'C8']
# ['B1', 'D2', 'F3', 'H4', 'C5', 'A6', 'G7', 'E8']
# ['B1', 'E2', 'G3', 'A4', 'C5', 'H6', 'F7', 'D8']
# ['B1', 'E2', 'G3', 'D4', 'A5', 'H6', 'F7', 'C8']
# ['B1', 'F2', 'A3', 'G4', 'D5', 'H6', 'C7', 'E8']
# ['B1', 'F2', 'H3', 'C4', 'A5', 'D6', 'G7', 'E8']
# ['B1', 'G2', 'C3', 'F4', 'H5', 'E6', 'A7', 'D8']
# ['B1', 'G2', 'E3', 'H4', 'A5', 'D6', 'F7', 'C8']
# ['B1', 'H2', 'F3', 'A4', 'C5', 'E6', 'G7', 'D8']
# ['C1', 'A2', 'G3', 'E4', 'H5', 'B6', 'D7', 'F8']
# ['C1', 'E2', 'B3', 'H4', 'A5', 'G6', 'D7', 'F8']
# ['C1', 'E2', 'B3', 'H4', 'F5', 'D6', 'G7', 'A8']
# ['C1', 'E2', 'G3', 'A4', 'D5', 'B6', 'H7', 'F8']
# ['C1', 'E2', 'H3', 'D4', 'A5', 'G6', 'B7', 'F8']
# ['C1', 'F2', 'B3', 'E4', 'H5', 'A6', 'G7', 'D8']
# ['C1', 'F2', 'B3', 'G4', 'A5', 'D6', 'H7', 'E8']
# ['C1', 'F2', 'B3', 'G4', 'E5', 'A6', 'H7', 'D8']
# ['C1', 'F2', 'D3', 'A4', 'H5', 'E6', 'G7', 'B8']
# ['C1', 'F2', 'D3', 'B4', 'H5', 'E6', 'G7', 'A8']
# ['C1', 'F2', 'H3', 'A4', 'D5', 'G6', 'E7', 'B8']
# ['C1', 'F2', 'H3', 'A4', 'E5', 'G6', 'B7', 'D8']
# ['C1', 'F2', 'H3', 'B4', 'D5', 'A6', 'G7', 'E8']
# ['C1', 'G2', 'B3', 'H4', 'E5', 'A6', 'D7', 'F8']
# ['C1', 'G2', 'B3', 'H4', 'F5', 'D6', 'A7', 'E8']
# ['C1', 'H2', 'D3', 'G4', 'A5', 'F6', 'B7', 'E8']
# ['D1', 'A2', 'E3', 'H4', 'B5', 'G6', 'C7', 'F8']
# ['D1', 'A2', 'E3', 'H4', 'F5', 'C6', 'G7', 'B8']
# ['D1', 'B2', 'E3', 'H4', 'F5', 'A6', 'C7', 'G8']
# ['D1', 'B2', 'G3', 'C4', 'F5', 'H6', 'A7', 'E8']
# ['D1', 'B2', 'G3', 'C4', 'F5', 'H6', 'E7', 'A8']
# ['D1', 'B2', 'G3', 'E4', 'A5', 'H6', 'F7', 'C8']
# ['D1', 'B2', 'H3', 'E4', 'G5', 'A6', 'C7', 'F8']
# ['D1', 'B2', 'H3', 'F4', 'A5', 'C6', 'E7', 'G8']
# ['D1', 'F2', 'A3', 'E4', 'B5', 'H6', 'C7', 'G8']
# ['D1', 'F2', 'H3', 'B4', 'G5', 'A6', 'C7', 'E8']
# ['D1', 'F2', 'H3', 'C4', 'A5', 'G6', 'E7', 'B8']
# ['D1', 'G2', 'A3', 'H4', 'E5', 'B6', 'F7', 'C8']
# ['D1', 'G2', 'C3', 'H4', 'B5', 'E6', 'A7', 'F8']
# ['D1', 'G2', 'E3', 'B4', 'F5', 'A6', 'C7', 'H8']
# ['D1', 'G2', 'E3', 'C4', 'A5', 'F6', 'H7', 'B8']
# ['D1', 'H2', 'A3', 'C4', 'F5', 'B6', 'G7', 'E8']
# ['D1', 'H2', 'A3', 'E4', 'G5', 'B6', 'F7', 'C8']
# ['D1', 'H2', 'E3', 'C4', 'A5', 'G6', 'B7', 'F8']
# ['E1', 'A2', 'D3', 'F4', 'H5', 'B6', 'G7', 'C8']
# ['E1', 'A2', 'H3', 'D4', 'B5', 'G6', 'C7', 'F8']
# ['E1', 'A2', 'H3', 'F4', 'C5', 'G6', 'B7', 'D8']
# ['E1', 'B2', 'D3', 'F4', 'H5', 'C6', 'A7', 'G8']
# ['E1', 'B2', 'D3', 'G4', 'C5', 'H6', 'F7', 'A8']
# ['E1', 'B2', 'F3', 'A4', 'G5', 'D6', 'H7', 'C8']
# ['E1', 'B2', 'H3', 'A4', 'D5', 'G6', 'C7', 'F8']
# ['E1', 'C2', 'A3', 'F4', 'H5', 'B6', 'D7', 'G8']
# ['E1', 'C2', 'A3', 'G4', 'B5', 'H6', 'F7', 'D8']
# ['E1', 'C2', 'H3', 'D4', 'G5', 'A6', 'F7', 'B8']
# ['E1', 'G2', 'A3', 'C4', 'H5', 'F6', 'D7', 'B8']
# ['E1', 'G2', 'A3', 'D4', 'B5', 'H6', 'F7', 'C8']
# ['E1', 'G2', 'B3', 'D4', 'H5', 'A6', 'C7', 'F8']
# ['E1', 'G2', 'B3', 'F4', 'C5', 'A6', 'D7', 'H8']
# ['E1', 'G2', 'B3', 'F4', 'C5', 'A6', 'H7', 'D8']
# ['E1', 'G2', 'D3', 'A4', 'C5', 'H6', 'F7', 'B8']
# ['E1', 'H2', 'D3', 'A4', 'C5', 'F6', 'B7', 'G8']
# ['E1', 'H2', 'D3', 'A4', 'G5', 'B6', 'F7', 'C8']
# ['F1', 'A2', 'E3', 'B4', 'H5', 'C6', 'G7', 'D8']
# ['F1', 'B2', 'G3', 'A4', 'C5', 'E6', 'H7', 'D8']
# ['F1', 'B2', 'G3', 'A4', 'D5', 'H6', 'E7', 'C8']
# ['F1', 'C2', 'A3', 'G4', 'E5', 'H6', 'B7', 'D8']
# ['F1', 'C2', 'A3', 'H4', 'D5', 'B6', 'G7', 'E8']
# ['F1', 'C2', 'A3', 'H4', 'E5', 'B6', 'D7', 'G8']
# ['F1', 'C2', 'E3', 'G4', 'A5', 'D6', 'B7', 'H8']
# ['F1', 'C2', 'E3', 'H4', 'A5', 'D6', 'B7', 'G8']
# ['F1', 'C2', 'G3', 'B4', 'D5', 'H6', 'A7', 'E8']
# ['F1', 'C2', 'G3', 'B4', 'H5', 'E6', 'A7', 'D8']
# ['F1', 'C2', 'G3', 'D4', 'A5', 'H6', 'B7', 'E8']
# ['F1', 'D2', 'A3', 'E4', 'H5', 'B6', 'G7', 'C8']
# ['F1', 'D2', 'B3', 'H4', 'E5', 'G6', 'A7', 'C8']
# ['F1', 'D2', 'G3', 'A4', 'C5', 'E6', 'B7', 'H8']
# ['F1', 'D2', 'G3', 'A4', 'H5', 'B6', 'E7', 'C8']
# ['F1', 'H2', 'B3', 'D4', 'A5', 'G6', 'E7', 'C8']
# ['G1', 'A2', 'C3', 'H4', 'F5', 'D6', 'B7', 'E8']
# ['G1', 'B2', 'D3', 'A4', 'H5', 'E6', 'C7', 'F8']
# ['G1', 'B2', 'F3', 'C4', 'A5', 'D6', 'H7', 'E8']
# ['G1', 'C2', 'A3', 'F4', 'H5', 'E6', 'B7', 'D8']
# ['G1', 'C2', 'H3', 'B4', 'E5', 'A6', 'F7', 'D8']
# ['G1', 'D2', 'B3', 'E4', 'H5', 'A6', 'C7', 'F8']
# ['G1', 'D2', 'B3', 'H4', 'F5', 'A6', 'C7', 'E8']
# ['G1', 'E2', 'C3', 'A4', 'F5', 'H6', 'B7', 'D8']
# ['H1', 'B2', 'D3', 'A4', 'G5', 'E6', 'C7', 'F8']
# ['H1', 'B2', 'E3', 'C4', 'A5', 'G6', 'D7', 'F8']
# ['H1', 'C2', 'A3', 'F4', 'B5', 'E6', 'G7', 'D8']
# ['H1', 'D2', 'A3', 'C4', 'F5', 'B6', 'G7', 'E8']

# %% [markdown]
# ### Вывод:

# %% [markdown]
# В данной лабораторной работе я реализовала различные методы поиска и и сравнила их время работы: интерполяционный поиск оказался самым быстрым.
